# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/kaggle/input/mall-customers/my.csv')

df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  k_mean
# 0           1       1   19                  15                      39       3
# 1           2       1   21                  15                      81       3
# 2           3       0   20                  16                       6       3
# 3           4       0   23                  16                      77       3
# 4           5       0   31                  17                      40       3

# %%
import os

os.listdir('/kaggle/input/mall-customers')
# Out:
# ['__results__.html',
#  'my.csv',
#  '__resultx__.html',
#  '__notebook__.ipynb',
#  '__results___files',
#  '__output__.json',
#  'custom.css']

# %%
# Graphique simple : âge des clients
plt.figure()
df['Age'].hist()
plt.xlabel('Age')
plt.ylabel('Nombre de clients')
plt.title('Distribution de l’âge des clients')
plt.show()
